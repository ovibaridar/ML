# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt 
import seaborn as sn

# %%
path = "/kaggle/input/netflix-all-movie-ratings-by-imdb/imdb_data.csv"

# %%
data = pd.read_csv(path)

# %%
data.head()
# Out:
#    Rating                                               Name
# 0     8.8                                  Inception\n(2010)
# 1     8.7                                 The Matrix\n(1999)
# 2     9.0  The Lord of the Rings: The Return of the King\...
# 3     8.8      The Lord of the Rings: The Two Towers\n(2002)
# 4     8.5                               The Departed\n(2006)

# %%
data [['Title', 'Year']] = data['Name'].str.extract(r'(.+)\s\((\d{4})\)')

# %%
data = data.drop("Name" , axis = 1)

# %%
data.head()
# Out:
#    Rating                                          Title  Year
# 0     8.8                                      Inception  2010
# 1     8.7                                     The Matrix  1999
# 2     9.0  The Lord of the Rings: The Return of the King  2003
# 3     8.8          The Lord of the Rings: The Two Towers  2002
# 4     8.5                                   The Departed  2006

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3740 entries, 0 to 3739
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rating  3728 non-null   float64
#  1   Title   3008 non-null   object
#  2   Year    3008 non-null   object
# dtypes: float64(1), object(2)
# memory usage: 87.8+ KB

# %%
data['Year'] = pd.to_numeric(data['Year'])

# %%
plt.hist(data['Rating'], bins=20, alpha=0.7)
plt.title('Distribution of IMDb Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.grid(True)
plt.tight_layout()

# %%
old_movie = data[(data["Year"] > 1980) & (data["Year"] < 2000)]
data = data[data["Year"] > 2000]

# %%
plt.figure(figsize=(20,10))
sn.barplot(data , x = "Year" , y = "Rating" , errorbar=None)
# Out:
# <Axes: xlabel='Year', ylabel='Rating'>

# %%
plt.figure(figsize=(10, 10))
plt.pie(old_movie["Year"].value_counts(), labels=old_movie["Year"].value_counts().index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Ratings for Old Movies')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
# Out:
# (-1.099999976702606, 1.0999999951630854, -1.09999999991783, 1.0999999999892422)
