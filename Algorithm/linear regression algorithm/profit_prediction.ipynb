# %%
import pandas as pd
from sklearn import linear_model 
from matplotlib import pyplot as plt

# %%
path='datasets/online.csv'

# %%
datas=pd.read_csv(path)

# %%
datas
# Out:
#     Marketing Spend  Administration  Transport     Profit
# 0         114523.61       136897.80  471784.10  192261.83
# 1         162597.70       151377.59  443898.53  191792.06
# 2         153441.51       101145.55  407934.54  191050.39
# 3         144372.41       118671.85  383199.62  182901.99
# 4         142107.34        91391.77  366168.42  166187.94
# 5         131876.90        99814.71  362861.36  156991.12
# 6         134615.46       147198.87  127716.82  156122.51
# 7         130298.13       145530.06  323876.68  155752.60
# 8         120542.52       148718.95  311613.29  152211.77
# 9         123334.88       108679.17  304981.62  149759.96
# 10        101913.08       110594.11  229160.95  146121.95
# 11        100671.96        91790.61  249744.55  144259.40
# 12         93863.75       127320.38  249839.44  141585.52
# 13         91992.39       135495.07  252664.93  134307.35
# 14        119943.24       156547.42  256512.92  132602.65
# ...

# %%
marketing_spend = datas['Marketing Spend']
profit = datas['Profit']

# %%
plt.scatter(marketing_spend, profit, label='Actual Profit',marker='+',color="b")
plt.xlabel('Marketing Spend')
plt.ylabel('Profit')
plt.legend()
plt.title('Actual vs. Predicted Profit')
plt.show()

# %%
rg.fit(datas[['Marketing Spend','Administration','Transport']],datas.Profit)
# Out:
# LinearRegression()

# %%
prediction = rg.predict([[153451.51, 101155.55, 407924.54]])
# Out:
# C:\Users\Ovi\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
prediction
# Out:
# array([180035.32546065])
